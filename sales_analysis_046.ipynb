# %% [markdown]
# 1.Write a Python program to draw line charts of the financial data of
# Alphabet Inc. between October 3, 2016 to October 7, 2016.
# Sample Financial data (fdata.csv):
# Date,Open,High,Low,Close
# 10-03-16,774.25,776.065002,769.5,772.559998
# 10-04-16,776.030029,778.710022,772.890015,776.429993
# 10-05-16,779.309998,782.070007,775.650024,776.469971
# 10-06-16,779,780.47998,775.539978,776.859985
# 10-07-16,779.659973,779.659973,770.75,775.080017

# %%
import pandas as pd
import matplotlib.pyplot as plt
csv_data = """Date,Open,High,Low,Close
10-03-16,774.25,776.065002,769.5,772.559998
10-04-16,776.030029,778.710022,772.890015,776.429993
10-05-16,779.309998,782.070007,775.650024,776.469971
10-06-16,779,780.47998,775.539978,776.859985
10-07-16,779.659973,779.659973,770.75,775.080017
"""
with open('fdata.csv', 'w') as f:
    f.write(csv_data)
data = pd.read_csv('fdata.csv')
data['Date'] = pd.to_datetime(data['Date'], format='%m-%d-%y')
data.set_index('Date', inplace=True)
plt.figure()
plt.plot(data.index, data['Open'], label='Open')
plt.plot(data.index, data['High'], label='High')
plt.plot(data.index, data['Low'], label='Low')
plt.plot(data.index, data['Close'], label='Close')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Alphabet Inc. Financial Data (Oct 3–7, 2016)')
plt.legend()
plt.show()

# %% [markdown]
# 2.Write a Python program to Program to show number of students vs
# marks obtained (Horizontal Bar Plot)
# nos = [2, 9, 20, 25, 30, 39]
# marks = [12, 24, 25, 27,29, 30]

# %%
import matplotlib.pyplot as plt
nos = [2, 9, 20, 25, 30, 39]
marks = [12, 24, 25, 27, 29, 30]
plt.barh(marks, nos)
plt.xlabel('Number of Students')
plt.ylabel('Marks Obtained')
plt.title('Students vs Marks')
plt.show()

# %% [markdown]
# 3.![Screenshot 2026-04-05 132217.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']

sales_2018 = [2500, 2200, 3000, 2800, 2750, 3500]
sales_2019 = [2600, 1800, 2500, 3000, 3200, 2000]
sales_2020 = [2450, 2000, 3000, 3100, 1950, 3550]
sales_2021 = [3250, 3200, 3800, 2800, 2900, 2300]
plt.plot(months, sales_2018, label='2018')
plt.plot(months, sales_2019, label='2019')
plt.plot(months, sales_2020, label='2020')
plt.plot(months, sales_2021, label='2021')
plt.title('Year-Wise Sales')
plt.xlabel('Months')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %% [markdown]
# 4.Assuming the same CSV file, i.e., monthsales.csv, plot the line chart
#
# with following customisations. Chart should have Month name on X-
# axis instead of numbers.
#
# Maker =”*”
# Marker size=10
# linestyle=”–“
# Linewidth =3

# %%
import matplotlib.pyplot as plt

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']

sales_2018 = [2500, 2200, 3000, 2800, 2750, 3500]
sales_2019 = [2600, 1800, 2500, 3000, 3200, 2000]
sales_2020 = [2450, 2000, 3000, 3100, 1950, 3550]
sales_2021 = [3250, 3200, 3800, 2800, 2900, 2300]
plt.plot(months, sales_2018, marker='*', markersize=10, linestyle='--', linewidth=3, label='2018')
plt.plot(months, sales_2019, marker='*', markersize=10, linestyle='--', linewidth=3, label='2019')
plt.plot(months, sales_2020, marker='*', markersize=10, linestyle='--', linewidth=3, label='2020')
plt.plot(months, sales_2021, marker='*', markersize=10, linestyle='--', linewidth=3, label='2021')
plt.title('Year-Wise Sales')
plt.xlabel('Months')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %% [markdown]
# 5.![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('emp.csv')
plt.bar(df['Department'], df['No_of_Emp'], color='red')
plt.title('Compu-Tech Employee Data')
plt.xlabel('Departments')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# 6.Visit data.gov.in , search for the following in “catalogs” option of the
# website:
# • Final population Totals, India and states
# • State Wise literacy rate Download them and create a CSV file containing
# population data and literacy rate of the respective state.
# Also add a column Region to the CSV file that should contain the values
# East, West, North and South.
# Plot a scatter plot for each region where X axis should be population and
# Y axis should be Literacy rate. Change the marker to a diamond and size
# as the square root of the literacy rate. Group the data on the column region
# and display a bar chart depicting average literacy rate for each region.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = {
    'State': ['Uttar Pradesh','Maharashtra','Bihar','Tamil Nadu','Karnataka','West Bengal','Gujarat','Punjab'],
    'Population': [199812341,112374333,104099452,72147030,61095297,91276115,60439692,27743338],
    'Literacy': [67.68,82.34,61.80,80.09,75.36,76.26,78.03,75.84],
    'Region': ['North','West','East','South','South','East','West','North']
}
df = pd.DataFrame(data)
for region in df['Region'].unique():
    subset = df[df['Region'] == region]

    plt.scatter(
        subset['Population'],
        subset['Literacy'],
        marker='D',
        s=np.sqrt(subset['Literacy']) * 10,
        label=region
    )
plt.xlabel('Population')
plt.ylabel('Literacy Rate')
plt.title('Population vs Literacy Rate by Region')
plt.legend()
plt.show()
avg_lit = df.groupby('Region')['Literacy'].mean()
avg_lit.plot(kind='bar')
plt.title('Average Literacy Rate by Region')
plt.xlabel('Region')
plt.ylabel('Literacy Rate')
plt.show()

# %% [markdown]
# 7.In order to assess the performance of students of a class in the annual
# examination, the class teacher stored marks of the students in all the 5
# subjects in a CSV “Marks.csv” file as shown in Table. Plot the data using
# boxplot and perform a comparative analysis of performance in each
# subject.![Screenshot 2026-04-05 133932.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {
    'Name': ['Rishika Batra','Waseem Ali','Kulpreet Singh','Annie Mathews'],
    'English': [95, 95, 78, 88],
    'Maths': [95, 76, 81, 63],
    'Hindi': [90, 79, 75, 67],
    'Science': [94, 77, 76, 77],
    'Social Studies': [95, 89, 88, 80]
}

df = pd.DataFrame(data)
df.boxplot(column=['English','Maths','Hindi','Science','Social Studies'])\
plt.title('Student Performance Analysis')
plt.ylabel('Marks')
plt.xlabel('Subjects')
plt.show()

# %% [markdown]
# 8.Write a Python program to create bar plot of scores by group and gender.
# Use multiple X values on the same chart for men and women.
# Sample Data:
# Means (men) = (22, 30, 35, 35, 26)
# Means (women) = (25, 32, 30, 35, 29)
# The code snippet gives the output shown in the following screenshot:![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
men_means = (22, 30, 35, 35, 26)
women_means = (25, 32, 30, 35, 29)
index = np.arange(len(men_means))
bar_width = 0.35
plt.bar(index, men_means, bar_width, label='Men')
plt.bar(index + bar_width, women_means, bar_width, label='Women')
plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Scores by person')
plt.xticks(index + bar_width / 2, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.legend()
plt.show()

# %% [markdown]
# 9.Use the following CSV file for this exercise
# https://drive.google.com/file/d/1FTV7KLn_PzOjVHrT9--
# 5hMaPKDfmr13X/view?usp=sharing
# a. Calculate total sale data for last year for each product and show it
# using a Pie chart
# Note: In pie chart display Number of units sold per year for each
# product in percentage
#
# b. Read Bathing soap facewash of all months and display it using the
# Subplot The Subplot should look like this.![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("sales_data.csv")
products = ['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer']
total_sales = [df[p].sum() for p in products]

plt.figure(figsize=(6,6))
plt.pie(total_sales, labels=products, autopct='%1.1f%%')
plt.title('Total Sales Data for Last Year')
plt.show()

months = df['month_number']

plt.figure(figsize=(8,6))

plt.subplot(2,1,1)
plt.plot(months, df['bathingsoap'], marker='o', color='black')
plt.title('Sales data of a Bathingsoap')

plt.subplot(2,1,2)
plt.plot(months, df['facewash'], marker='o', color='red')
plt.title('Sales data of a facewash')

plt.xlabel('Month Number')
plt.ylabel('Sales units')

plt.tight_layout()
plt.show()

profit = df['total_profit']

plt.figure(figsize=(8,5))
plt.hist(profit, bins=6)
plt.title("Profit data")
plt.xlabel("profit range in dollar")
plt.ylabel("Actual Profit in dollar")
plt.legend(['Profit data'])

plt.show()

# %% [markdown]
# 10.Read the total profit of each month and show it using the histogram to
# see the most common profit ranges
#
# The histogram should look like this.![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("sales_data.csv")

profit_list = df['total_profit'].tolist()

plt.figure(figsize=(10, 6))

profit_range = [150000, 175000, 200000, 225000, 250000, 300000, 350000]
plt.hist(profit_list, bins=profit_range, label='Profit data')

plt.xlabel('profit range in dollar')
plt.ylabel('Actual Profit in dollar')
plt.legend(loc='upper left')
plt.title('Profit data')

plt.xticks(profit_range)
plt.show()

# %%
df.to_csv("sales_data.csv", index=False)
from google.colab import files
files.download("sales_data.csv")
